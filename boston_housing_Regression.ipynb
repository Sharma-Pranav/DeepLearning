# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharma-Pranav/DeepLearning/blob/master/boston_housing_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import boston_housing
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
(X_train, Y_train), (X_test, Y_test) = boston_housing.load_data()
print(X_train.shape, Y_train.shape)
print(Y_train[0])
# Out:
# (404, 13) (404,)
# 15.2

# %%
model = Sequential()

# %%
# Keras model with two hidden layer with 10 neurons each
model.add(Dense(512, input_shape = (13,), activation = 'sigmoid'))
model.add(Dense(256, activation = 'sigmoid'))
model.add(Dense(128, activation = 'sigmoid'))
model.add(Dense(1))

# %%
sgd = optimizers.Adam()
model.compile(optimizer = sgd, loss = 'mean_squared_error', metrics = ['mse'])
model.fit(X_train, Y_train, batch_size = 128, epochs = 500, verbose =1)
# Out:
# Epoch 1/500
# 404/404 [==============================] - 0s 1ms/step - loss: 96.7046 - mean_squared_error: 96.7046
# Epoch 2/500
# 404/404 [==============================] - 0s 75us/step - loss: 82.4280 - mean_squared_error: 82.4280
# Epoch 3/500
# 404/404 [==============================] - 0s 88us/step - loss: 82.9458 - mean_squared_error: 82.9458
# Epoch 4/500
# 404/404 [==============================] - 0s 71us/step - loss: 81.4262 - mean_squared_error: 81.4262
# Epoch 5/500
# 404/404 [==============================] - 0s 67us/step - loss: 83.5017 - mean_squared_error: 83.5017
# Epoch 6/500
# 404/404 [==============================] - 0s 68us/step - loss: 83.6339 - mean_squared_error: 83.6339
# Epoch 7/500
# 404/404 [==============================] - 0s 68us/step - loss: 81.5661 - mean_squared_error: 81.5661
# Epoch 8/500
# 404/404 [==============================] - 0s 71us/step - loss: 80.5358 - mean_squared_error: 80.5358
# Epoch 9/500
# ...

# %%
results = model.evaluate(X_test, Y_test)
print('loss: ', results[0])
print('mse: ', results[1])
# Out:
# 102/102 [==============================] - 0s 474us/step
# loss:  77.79684298646217
# mse:  77.79684298646217
